# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Rio_de_Janeiro_Brasil_sin_valores_nulos.csv")
data.head()
# Out:
#    Unnamed: 0 last_scraped       source  \
# 0           0   25/09/2024  city scrape
# 1           1   25/09/2024  city scrape
# 2           2   26/09/2024  city scrape
# 3           3   25/09/2024  city scrape
# 4           4   25/09/2024  city scrape
#
#                                                 name  \
# 0                     Fascinating Rio, on the hills!
# 1                           STUDIO RIO LAPA CARNIVAL
# 2  5 min a pÃ© - Praia de Copacabana, MetrÃ´, WiFi I
# 3  Quintal da Lagoa -  RefÃºgio Secreto quase Ipa...
# 4                    Rio, hospedagem e tranquilidade
#
#                                          description  \
# 0  Your best option to stay if you want to visit ...
# 1  The studio is in an excellent location ,  dire...
# 2  Bedroom and living room, with a private bathro...
# 3  Our apartment is the perfect choice for those ...
# 4  Your best option to stay if you want to visit ...
#
#                                neighborhood_overview        host_name  \
# 0  Quiet and safe area, with the characteristics ...  Marcia  Longras
# 1  Quiet and safe area, with the characteristics ...            Erika
# 2  We are in Copacabana on the border with Ipanem...   Renato / Louri
# 3  Lagoa is a charming neighborhood very close to...            Nilda
# 4                   Quiet neighbors, family building        Jaqueline
#
#    host_since           host_location  \
# 0  09/04/2011  Rio de Janeiro, Brazil
# 1  02/12/2011  Rio de Janeiro, Brazil
# 2  18/03/2011  Rio de Janeiro, Brazil
# 3  06/09/2011  Rio de Janeiro, Brazil
# 4  04/12/2011  Rio de Janeiro, Brazil
#
#                                           host_about  ...  \
# 0  I'm a Brazilian lady, I was born in Rio de Jan...  ...
# 1  Sou Erika tenho 37 anos ,casada,  formada em  ...  ...
# 2  *French version below \r\n\r\nWe host internat...  ...
# 3  Gosto de conhecer  pessoas e novas culturas e ...  ...
# 4   SimpÃ¡tica e gosto de novos amigos. Meu lazer...  ...
#
#   review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 0                 4.69                   4.82                      4.58
# 1                 4.67                   5.00                      4.00
# 2                 4.71                   4.82                      4.79
# 3                 5.00                   4.94                      5.00
# 4                 4.68                   4.80                      4.76
#
#   review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                  4.73                         4.85                    4.64
# 1                  4.67                         5.00                    4.67
# 2                  4.82                         4.88                    4.41
# 3                  5.00                         5.00                    4.83
# 4                  4.80                         4.83                    4.77
#
#   review_scores_value instant_bookable calculated_host_listings_count  \
# 0                4.64                f                             11
# 1                4.67                f                              3
# 2                4.65                f                              6
# 3                4.92                f                              1
# 4                4.60                f                              1
#
#   reviews_per_month
# 0              0.22
# 1              0.02
# 2              0.22
# 3              0.51
# 4              0.24
#
# [5 rows x 51 columns]

# %%
data=data.drop(columns='Unnamed: 0')
data.head()
# Out:
#   last_scraped       source  \
# 0   25/09/2024  city scrape
# 1   25/09/2024  city scrape
# 2   26/09/2024  city scrape
# 3   25/09/2024  city scrape
# 4   25/09/2024  city scrape
#
#                                                 name  \
# 0                     Fascinating Rio, on the hills!
# 1                           STUDIO RIO LAPA CARNIVAL
# 2  5 min a pÃ© - Praia de Copacabana, MetrÃ´, WiFi I
# 3  Quintal da Lagoa -  RefÃºgio Secreto quase Ipa...
# 4                    Rio, hospedagem e tranquilidade
#
#                                          description  \
# 0  Your best option to stay if you want to visit ...
# 1  The studio is in an excellent location ,  dire...
# 2  Bedroom and living room, with a private bathro...
# 3  Our apartment is the perfect choice for those ...
# 4  Your best option to stay if you want to visit ...
#
#                                neighborhood_overview        host_name  \
# 0  Quiet and safe area, with the characteristics ...  Marcia  Longras
# 1  Quiet and safe area, with the characteristics ...            Erika
# 2  We are in Copacabana on the border with Ipanem...   Renato / Louri
# 3  Lagoa is a charming neighborhood very close to...            Nilda
# 4                   Quiet neighbors, family building        Jaqueline
#
#    host_since           host_location  \
# 0  09/04/2011  Rio de Janeiro, Brazil
# 1  02/12/2011  Rio de Janeiro, Brazil
# 2  18/03/2011  Rio de Janeiro, Brazil
# 3  06/09/2011  Rio de Janeiro, Brazil
# 4  04/12/2011  Rio de Janeiro, Brazil
#
#                                           host_about  host_response_time  ...  \
# 0  I'm a Brazilian lady, I was born in Rio de Jan...  within a few hours  ...
# 1  Sou Erika tenho 37 anos ,casada,  formada em  ...        within a day  ...
# 2  *French version below \r\n\r\nWe host internat...      within an hour  ...
# 3  Gosto de conhecer  pessoas e novas culturas e ...      within an hour  ...
# 4   SimpÃ¡tica e gosto de novos amigos. Meu lazer...        within a day  ...
#
#   review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 0                 4.69                   4.82                      4.58
# 1                 4.67                   5.00                      4.00
# 2                 4.71                   4.82                      4.79
# 3                 5.00                   4.94                      5.00
# 4                 4.68                   4.80                      4.76
#
#    review_scores_checkin  review_scores_communication review_scores_location  \
# 0                   4.73                         4.85                   4.64
# 1                   4.67                         5.00                   4.67
# 2                   4.82                         4.88                   4.41
# 3                   5.00                         5.00                   4.83
# 4                   4.80                         4.83                   4.77
#
#   review_scores_value instant_bookable calculated_host_listings_count  \
# 0                4.64                f                             11
# 1                4.67                f                              3
# 2                4.65                f                              6
# 3                4.92                f                              1
# 4                4.60                f                              1
#
#   reviews_per_month
# 0              0.22
# 1              0.02
# 2              0.22
# 3              0.51
# 4              0.24
#
# [5 rows x 50 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36967 entries, 0 to 36966
# Data columns (total 50 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   last_scraped                    36967 non-null  object
#  1   source                          36967 non-null  object
#  2   name                            36967 non-null  object
#  3   description                     36967 non-null  object
#  4   neighborhood_overview           36967 non-null  object
#  5   host_name                       36967 non-null  object
#  6   host_since                      36967 non-null  object
#  7   host_location                   36967 non-null  object
#  8   host_about                      36967 non-null  object
#  9   host_response_time              36967 non-null  object
#  10  host_response_rate              36967 non-null  object
#  11  host_acceptance_rate            36967 non-null  object
#  12  host_is_superhost               36967 non-null  object
#  13  host_listings_count             36967 non-null  int64
#  14  host_total_listings_count       36967 non-null  int64
#  15  host_verifications              36967 non-null  object
#  16  host_has_profile_pic            36967 non-null  object
#  17  host_identity_verified          36967 non-null  object
#  18  neighbourhood_cleansed          36967 non-null  object
#  19  property_type                   36967 non-null  object
#  20  room_type                       36967 non-null  object
#  21  accommodates                    36967 non-null  int64
#  22  bathrooms                       36967 non-null  float64
#  23  bedrooms                        36967 non-null  float64
#  24  beds                            36967 non-null  float64
#  25  amenities                       36967 non-null  object
#  26  price                           36967 non-null  float64
#  27  minimum_nights                  36967 non-null  int64
#  28  maximum_nights                  36967 non-null  int64
#  29  minimum_nights_avg_ntm          36967 non-null  float64
#  30  maximum_nights_avg_ntm          36967 non-null  float64
#  31  has_availability                36967 non-null  object
#  32  availability_30                 36967 non-null  int64
#  33  availability_60                 36967 non-null  int64
#  34  availability_90                 36967 non-null  int64
#  35  availability_365                36967 non-null  int64
#  36  number_of_reviews_ltm           36967 non-null  int64
#  37  number_of_reviews_l30d          36967 non-null  int64
#  38  first_review                    36967 non-null  object
#  39  last_review                     36967 non-null  object
#  40  review_scores_rating            36967 non-null  float64
#  41  review_scores_accuracy          36967 non-null  float64
#  42  review_scores_cleanliness       36967 non-null  float64
#  43  review_scores_checkin           36967 non-null  float64
#  44  review_scores_communication     36967 non-null  float64
#  45  review_scores_location          36967 non-null  float64
#  46  review_scores_value             36967 non-null  float64
#  47  instant_bookable                36967 non-null  object
#  48  calculated_host_listings_count  36967 non-null  int64
#  49  reviews_per_month               36967 non-null  float64
# dtypes: float64(14), int64(12), object(24)
# memory usage: 14.1+ MB

# %%
cualitativas=data.iloc[:,[0,1,2,3,5,6,7,8,9,10,11,12,15,16,17,18,19,20,25,31,38,39,47]]
#float64
cuantitativas=data.iloc[:,[13,14,21,22,23,24,26,27,28,29,30,32,33,34,35,36,37,40,41,42,43,44,45,46,48,49]]

# %%
fig=plt.figure(figsize=(15,8))
cuantitativas.plot(kind='box',vert=False)
plt.title("valores atipicos del dataframe")
plt.show()

# %% [markdown]
# **PROCEDIMIENTO DE CUANTILES PATA SUSTITUIR OUTLINERS EN DATAFRAME**

# %%
y=cuantitativas
percentile25=y.quantile(0.25)#Q1
percentile75=y.quantile(0.75)#Q3
iqr=percentile75-percentile25
Limite_Superior_iqr=percentile75+1.5*iqr
Limite_Inferior_iqr=percentile25-1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido host_listings_count                 13.500
# host_total_listings_count           21.000
# accommodates                         9.500
# bathrooms                            3.500
# bedrooms                             3.500
# beds                                 6.000
# price                             1132.000
# minimum_nights                       6.000
# maximum_nights                     822.500
# minimum_nights_avg_ntm               5.950
# maximum_nights_avg_ntm            2677.500
# availability_30                     59.000
# availability_60                    108.500
# availability_90                    153.500
# availability_365                   684.000
# number_of_reviews_ltm               25.000
# number_of_reviews_l30d               2.500
# review_scores_rating                 5.270
# review_scores_accuracy               5.300
# review_scores_cleanliness            5.330
# review_scores_checkin                5.150
# review_scores_communication          5.150
# review_scores_location               5.150
# review_scores_value                  5.245
# calculated_host_listings_count      11.000
# reviews_per_month                    2.550
# dtype: float64
# Limite inferior permitido host_listings_count                 -6.500
# host_total_listings_count          -11.000
# accommodates                        -2.500
# bathrooms                           -0.500
# bedrooms                            -0.500
# beds                                -2.000
# price                             -340.000
# minimum_nights                      -2.000
# maximum_nights                    -397.500
# minimum_nights_avg_ntm              -1.650
# maximum_nights_avg_ntm           -1462.500
# availability_30                    -21.000
# availability_60                    -23.500
# availability_90                    -18.500
# availability_365                  -268.000
# number_of_reviews_ltm              -15.000
# number_of_reviews_l30d              -1.500
# review_scores_rating                 4.550
# review_scores_accuracy               4.500
# review_scores_cleanliness            4.450
# review_scores_checkin                4.750
# review_scores_communication          4.750
# review_scores_location               4.750
# review_scores_value                  4.405
# calculated_host_listings_count      -5.000
# reviews_per_month                   -0.970
# dtype: float64

# %%
#obtenemos datos limpios del dataframe
data3_iqr=cuantitativas[(y<=Limite_Superior_iqr) & (y>=Limite_Inferior_iqr)]
data3_iqr
# Out:
#        host_listings_count  host_total_listings_count  accommodates  \
# 0                     12.0                       14.0           2.0
# 1                      3.0                        5.0           2.0
# 2                     11.0                       12.0           4.0
# 3                      1.0                        2.0           4.0
# 4                      1.0                        2.0           2.0
# ...                    ...                        ...           ...
# 36962                  NaN                        NaN           3.0
# 36963                  1.0                        1.0           6.0
# 36964                  4.0                        7.0           4.0
# 36965                  2.0                        2.0           2.0
# 36966                  6.0                        7.0           4.0
#
#        bathrooms  bedrooms  beds  price  minimum_nights  maximum_nights  \
# 0            2.0       1.0   1.0  270.0             5.0           358.0
# 1            1.0       0.0   4.0  300.0             NaN           365.0
# 2            1.0       1.0   1.0  279.0             6.0            90.0
# 3            2.0       2.0   2.0  447.0             3.0            30.0
# 4            1.0       1.0   1.0  354.0             2.0            15.0
# ...          ...       ...   ...    ...             ...             ...
# 36962        1.0       1.0   3.0  125.0             1.0           365.0
# 36963        1.0       1.0   2.0  232.0             1.0           365.0
# 36964        1.0       1.0   2.0  200.0             1.0           365.0
# 36965        1.0       1.0   1.0  171.0             1.0           365.0
# 36966        1.0       1.0   2.0  300.0             1.0           365.0
#
#        minimum_nights_avg_ntm  ...  number_of_reviews_l30d  \
# 0                         5.0  ...                     1.0
# 1                         NaN  ...                     0.0
# 2                         5.7  ...                     0.0
# 3                         3.2  ...                     2.0
# 4                         2.0  ...                     0.0
# ...                       ...  ...                     ...
# 36962                     1.0  ...                     0.0
# 36963                     1.4  ...                     0.0
# 36964                     1.0  ...                     0.0
# 36965                     1.0  ...                     0.0
# 36966                     1.0  ...                     0.0
#
#        review_scores_rating  review_scores_accuracy  \
# 0                      4.69                    4.82
# 1                      4.67                    5.00
# 2                      4.71                    4.82
# 3                      5.00                    4.94
# 4                      4.68                    4.80
# ...                     ...                     ...
# 36962                  4.90                    4.80
# 36963                  4.90                    4.80
# 36964                  4.90                    4.80
# 36965                  4.90                    4.80
# 36966                  4.90                    4.80
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.58                    NaN
# 1                            NaN                    NaN
# 2                           4.79                   4.82
# 3                           5.00                   5.00
# 4                           4.76                   4.80
# ...                          ...                    ...
# 36962                       4.80                   4.90
# 36963                       4.80                   4.90
# 36964                       4.80                   4.90
# 36965                       4.80                   4.90
# 36966                       4.80                   4.90
#
#        review_scores_communication  review_scores_location  \
# 0                             4.85                     NaN
# 1                             5.00                     NaN
# 2                             4.88                     NaN
# 3                             5.00                    4.83
# 4                             4.83                    4.77
# ...                            ...                     ...
# 36962                         4.90                    4.90
# 36963                         4.90                    4.90
# 36964                         4.90                    4.90
# 36965                         4.90                    4.90
# 36966                         4.90                    4.90
#
#        review_scores_value  calculated_host_listings_count  reviews_per_month
# 0                     4.64                            11.0               0.22
# 1                     4.67                             3.0               0.02
# 2                     4.65                             6.0               0.22
# 3                     4.92                             1.0               0.51
# 4                     4.60                             1.0               0.24
# ...                    ...                             ...                ...
# 36962                 4.80                             NaN               0.70
# 36963                 4.80                             1.0               0.70
# 36964                 4.80                             4.0               0.70
# 36965                 4.80                             2.0               0.70
# 36966                 4.80                             6.0               0.70
#
# [36967 rows x 26 columns]

# %%
valores_nulos=data3_iqr.isnull().sum()
valores_nulos
# Out:
# host_listings_count               5954
# host_total_listings_count         5459
# accommodates                      1275
# bathrooms                         1152
# bedrooms                          1343
# beds                               991
# price                             3566
# minimum_nights                    2190
# maximum_nights                    7754
# minimum_nights_avg_ntm            2507
# maximum_nights_avg_ntm               0
# availability_30                      0
# availability_60                      0
# availability_90                      0
# availability_365                     0
# number_of_reviews_ltm             3293
# number_of_reviews_l30d            3954
# review_scores_rating              3232
# review_scores_accuracy            2132
# review_scores_cleanliness         2985
# review_scores_checkin             3212
# review_scores_communication       3706
# review_scores_location            4417
# review_scores_value               3153
# calculated_host_listings_count    5595
# reviews_per_month                 3292
# dtype: int64

# %%
data4_iqr=data3_iqr.copy()
data4_iqr=data4_iqr.fillna(round(data3_iqr.mean(),1))
data4_iqr
# Out:
#        host_listings_count  host_total_listings_count  accommodates  \
# 0                     12.0                       14.0           2.0
# 1                      3.0                        5.0           2.0
# 2                     11.0                       12.0           4.0
# 3                      1.0                        2.0           4.0
# 4                      1.0                        2.0           2.0
# ...                    ...                        ...           ...
# 36962                  2.7                        4.0           3.0
# 36963                  1.0                        1.0           6.0
# 36964                  4.0                        7.0           4.0
# 36965                  2.0                        2.0           2.0
# 36966                  6.0                        7.0           4.0
#
#        bathrooms  bedrooms  beds  price  minimum_nights  maximum_nights  \
# 0            2.0       1.0   1.0  270.0             5.0           358.0
# 1            1.0       0.0   4.0  300.0             2.2           365.0
# 2            1.0       1.0   1.0  279.0             6.0            90.0
# 3            2.0       2.0   2.0  447.0             3.0            30.0
# 4            1.0       1.0   1.0  354.0             2.0            15.0
# ...          ...       ...   ...    ...             ...             ...
# 36962        1.0       1.0   3.0  125.0             1.0           365.0
# 36963        1.0       1.0   2.0  232.0             1.0           365.0
# 36964        1.0       1.0   2.0  200.0             1.0           365.0
# 36965        1.0       1.0   1.0  171.0             1.0           365.0
# 36966        1.0       1.0   2.0  300.0             1.0           365.0
#
#        minimum_nights_avg_ntm  ...  number_of_reviews_l30d  \
# 0                         5.0  ...                     1.0
# 1                         2.3  ...                     0.0
# 2                         5.7  ...                     0.0
# 3                         3.2  ...                     2.0
# 4                         2.0  ...                     0.0
# ...                       ...  ...                     ...
# 36962                     1.0  ...                     0.0
# 36963                     1.4  ...                     0.0
# 36964                     1.0  ...                     0.0
# 36965                     1.0  ...                     0.0
# 36966                     1.0  ...                     0.0
#
#        review_scores_rating  review_scores_accuracy  \
# 0                      4.69                    4.82
# 1                      4.67                    5.00
# 2                      4.71                    4.82
# 3                      5.00                    4.94
# 4                      4.68                    4.80
# ...                     ...                     ...
# 36962                  4.90                    4.80
# 36963                  4.90                    4.80
# 36964                  4.90                    4.80
# 36965                  4.90                    4.80
# 36966                  4.90                    4.80
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.58                   4.90
# 1                           4.90                   4.90
# 2                           4.79                   4.82
# 3                           5.00                   5.00
# 4                           4.76                   4.80
# ...                          ...                    ...
# 36962                       4.80                   4.90
# 36963                       4.80                   4.90
# 36964                       4.80                   4.90
# 36965                       4.80                   4.90
# 36966                       4.80                   4.90
#
#        review_scores_communication  review_scores_location  \
# 0                             4.85                    4.90
# 1                             5.00                    4.90
# 2                             4.88                    4.90
# 3                             5.00                    4.83
# 4                             4.83                    4.77
# ...                            ...                     ...
# 36962                         4.90                    4.90
# 36963                         4.90                    4.90
# 36964                         4.90                    4.90
# 36965                         4.90                    4.90
# 36966                         4.90                    4.90
#
#        review_scores_value  calculated_host_listings_count  reviews_per_month
# 0                     4.64                            11.0               0.22
# 1                     4.67                             3.0               0.02
# 2                     4.65                             6.0               0.22
# 3                     4.92                             1.0               0.51
# 4                     4.60                             1.0               0.24
# ...                    ...                             ...                ...
# 36962                 4.80                             2.4               0.70
# 36963                 4.80                             1.0               0.70
# 36964                 4.80                             4.0               0.70
# 36965                 4.80                             2.0               0.70
# 36966                 4.80                             6.0               0.70
#
# [36967 rows x 26 columns]

# %%
#unmos el dataframe cuantitativo limpio con el dataframe caulitativo
Datos_limpios=pd.concat([cualitativas,data4_iqr],axis=1)
Datos_limpios
# Out:
#       last_scraped       source  \
# 0       25/09/2024  city scrape
# 1       25/09/2024  city scrape
# 2       26/09/2024  city scrape
# 3       25/09/2024  city scrape
# 4       25/09/2024  city scrape
# ...            ...          ...
# 36962   25/09/2024  city scrape
# 36963   26/09/2024  city scrape
# 36964   25/09/2024  city scrape
# 36965   25/09/2024  city scrape
# 36966   25/09/2024  city scrape
#
#                                                     name  \
# 0                         Fascinating Rio, on the hills!
# 1                               STUDIO RIO LAPA CARNIVAL
# 2      5 min a pÃ© - Praia de Copacabana, MetrÃ´, WiFi I
# 3      Quintal da Lagoa -  RefÃºgio Secreto quase Ipa...
# 4                        Rio, hospedagem e tranquilidade
# ...                                                  ...
# 36962                                       Maravilha 15
# 36963                    Sua casa na praia de Copacabana
# 36964                     Apt a 300m da praia do Recreio
# 36965                                       Casa da Dety
# 36966                     Apt a 300m da Praia do Recreio
#
#                                              description        host_name  \
# 0      Your best option to stay if you want to visit ...  Marcia  Longras
# 1      The studio is in an excellent location ,  dire...            Erika
# 2      Bedroom and living room, with a private bathro...   Renato / Louri
# 3      Our apartment is the perfect choice for those ...            Nilda
# 4      Your best option to stay if you want to visit ...        Jaqueline
# ...                                                  ...              ...
# 36962  Embrace simplicity in this quiet and well-loca...   Sara Regina De
# 36963  Welcome to your getaway in Copacabana! This ap...   Nathalia Simon
# 36964  Relax with the whole family in this quiet acco...           Robert
# 36965  You will have a great time in this comfortable...  Antonia Eridete
# 36966  Relax with the whole family in this quiet acco...           Robert
#
#        host_since           host_location  \
# 0      09/04/2011  Rio de Janeiro, Brazil
# 1      02/12/2011  Rio de Janeiro, Brazil
# 2      18/03/2011  Rio de Janeiro, Brazil
# 3      06/09/2011  Rio de Janeiro, Brazil
# 4      04/12/2011  Rio de Janeiro, Brazil
# ...           ...                     ...
# 36962  20/01/2017  Rio de Janeiro, Brazil
# 36963  05/10/2015  Rio de Janeiro, Brazil
# 36964  07/08/2024  Rio de Janeiro, Brazil
# 36965  03/02/2024     Mexico City, Mexico
# 36966  22/05/2018  Rio de Janeiro, Brazil
#
#                                               host_about  host_response_time  \
# 0      I'm a Brazilian lady, I was born in Rio de Jan...  within a few hours
# 1      Sou Erika tenho 37 anos ,casada,  formada em  ...        within a day
# 2      *French version below \r\n\r\nWe host internat...      within an hour
# 3      Gosto de conhecer  pessoas e novas culturas e ...      within an hour
# 4       SimpÃ¡tica e gosto de novos amigos. Meu lazer...        within a day
# ...                                                  ...                 ...
# 36962  I am a social person, who likes to provide the...      within an hour
# 36963  I am a social person, who likes to provide the...        within a day
# 36964  I am a social person, who likes to provide the...      within an hour
# 36965  I am a social person, who likes to provide the...      within an hour
# 36966  I am a social person, who likes to provide the...      within an hour
#
#       host_response_rate  ... number_of_reviews_l30d review_scores_rating  \
# 0                    93%  ...                    1.0                 4.69
# 1                    50%  ...                    0.0                 4.67
# 2                    99%  ...                    0.0                 4.71
# 3                   100%  ...                    2.0                 5.00
# 4                    50%  ...                    0.0                 4.68
# ...                  ...  ...                    ...                  ...
# 36962               100%  ...                    0.0                 4.90
# 36963                89%  ...                    0.0                 4.90
# 36964               100%  ...                    0.0                 4.90
# 36965               100%  ...                    0.0                 4.90
# 36966               100%  ...                    0.0                 4.90
#
#       review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 0                       4.82                      4.58                  4.90
# 1                       5.00                      4.90                  4.90
# 2                       4.82                      4.79                  4.82
# 3                       4.94                      5.00                  5.00
# 4                       4.80                      4.76                  4.80
# ...                      ...                       ...                   ...
# 36962                   4.80                      4.80                  4.90
# 36963                   4.80                      4.80                  4.90
# 36964                   4.80                      4.80                  4.90
# 36965                   4.80                      4.80                  4.90
# 36966                   4.80                      4.80                  4.90
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                            4.85                   4.90                4.64
# 1                            5.00                   4.90                4.67
# 2                            4.88                   4.90                4.65
# 3                            5.00                   4.83                4.92
# 4                            4.83                   4.77                4.60
# ...                           ...                    ...                 ...
# 36962                        4.90                   4.90                4.80
# 36963                        4.90                   4.90                4.80
# 36964                        4.90                   4.90                4.80
# 36965                        4.90                   4.90                4.80
# 36966                        4.90                   4.90                4.80
#
#       calculated_host_listings_count reviews_per_month
# 0                               11.0              0.22
# 1                                3.0              0.02
# 2                                6.0              0.22
# 3                                1.0              0.51
# 4                                1.0              0.24
# ...                              ...               ...
# 36962                            2.4              0.70
# 36963                            1.0              0.70
# 36964                            4.0              0.70
# 36965                            2.0              0.70
# 36966                            6.0              0.70
#
# [36967 rows x 49 columns]

# %%
valores_nulos=Datos_limpios.isnull().sum().sum()
valores_nulos
# Out:
# np.int64(0)

# %% [markdown]
# **Procedimiento "DESVIACION ESTANDAR" PARA ELIMINAR OUTLINERS EN DATAFRAME**

# %%
#METODO APLICANDO DESVIACION ESTANDAR. ENCUENTRO LOS VALORES
y=cuantitativas
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite Superior permitido", Limite_Superior)
print("Limite Inferior permitido", Limite_Inferior)
# Out:
# Limite Superior permitido host_listings_count                 286.806595
# host_total_listings_count           496.780308
# accommodates                         10.982800
# bathrooms                             4.458766
# bedrooms                              4.651843
# beds                                  8.606675
# price                             16738.270856
# minimum_nights                       45.063717
# maximum_nights                     1610.895633
# minimum_nights_avg_ntm               42.182068
# maximum_nights_avg_ntm             1836.697199
# availability_30                      52.792911
# availability_60                     105.091096
# availability_90                     156.104597
# availability_365                    562.490429
# number_of_reviews_ltm                43.918510
# number_of_reviews_l30d                4.902218
# review_scores_rating                  5.773590
# review_scores_accuracy                5.736824
# review_scores_cleanliness             5.817374
# review_scores_checkin                 5.644767
# review_scores_communication           5.657717
# review_scores_location                5.613905
# review_scores_value                   5.794715
# calculated_host_listings_count       84.649218
# reviews_per_month                     4.294794
# dtype: float64
# Limite Inferior permitido host_listings_count                -253.122553
# host_total_listings_count          -439.672617
# accommodates                         -2.998489
# bathrooms                            -1.443590
# bedrooms                             -1.572989
# beds                                 -3.855844
# price                            -15317.197899
# minimum_nights                      -37.898353
# maximum_nights                     -809.564283
# minimum_nights_avg_ntm              -34.805581
# maximum_nights_avg_ntm             -820.683522
# availability_30                     -14.244097
# availability_60                     -22.963199
# availability_90                     -28.174821
# availability_365                   -167.106924
# number_of_reviews_ltm               -28.457044
# number_of_reviews_l30d               -3.259294
# review_scores_rating                  3.886758
# review_scores_accuracy                3.895479
# review_scores_cleanliness             3.739440
# review_scores_checkin                 4.144251
# review_scores_communication           4.117272
# review_scores_location                4.138421
# review_scores_value                   3.696302
# calculated_host_listings_count      -65.688902
# reviews_per_month                    -2.241327
# dtype: float64

# %%
#obtenemos datos y los outliners se convierten en nulos en el DataFrame 
data3=cuantitativas[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data3
# Out:
#        host_listings_count  host_total_listings_count  accommodates  \
# 0                     12.0                       14.0           2.0
# 1                      3.0                        5.0           2.0
# 2                     11.0                       12.0           4.0
# 3                      1.0                        2.0           4.0
# 4                      1.0                        2.0           2.0
# ...                    ...                        ...           ...
# 36962                 26.0                       26.0           3.0
# 36963                  1.0                        1.0           6.0
# 36964                  4.0                        7.0           4.0
# 36965                  2.0                        2.0           2.0
# 36966                  6.0                        7.0           4.0
#
#        bathrooms  bedrooms  beds  price  minimum_nights  maximum_nights  \
# 0            2.0       1.0   1.0  270.0             5.0             358
# 1            1.0       0.0   4.0  300.0             7.0             365
# 2            1.0       1.0   1.0  279.0             6.0              90
# 3            2.0       2.0   2.0  447.0             3.0              30
# 4            1.0       1.0   1.0  354.0             2.0              15
# ...          ...       ...   ...    ...             ...             ...
# 36962        1.0       1.0   3.0  125.0             1.0             365
# 36963        1.0       1.0   2.0  232.0             1.0             365
# 36964        1.0       1.0   2.0  200.0             1.0             365
# 36965        1.0       1.0   1.0  171.0             1.0             365
# 36966        1.0       1.0   2.0  300.0             1.0             365
#
#        minimum_nights_avg_ntm  ...  number_of_reviews_l30d  \
# 0                         5.0  ...                     1.0
# 1                         7.0  ...                     0.0
# 2                         5.7  ...                     0.0
# 3                         3.2  ...                     2.0
# 4                         2.0  ...                     0.0
# ...                       ...  ...                     ...
# 36962                     1.0  ...                     0.0
# 36963                     1.4  ...                     0.0
# 36964                     1.0  ...                     0.0
# 36965                     1.0  ...                     0.0
# 36966                     1.0  ...                     0.0
#
#        review_scores_rating  review_scores_accuracy  \
# 0                      4.69                    4.82
# 1                      4.67                    5.00
# 2                      4.71                    4.82
# 3                      5.00                    4.94
# 4                      4.68                    4.80
# ...                     ...                     ...
# 36962                  4.90                    4.80
# 36963                  4.90                    4.80
# 36964                  4.90                    4.80
# 36965                  4.90                    4.80
# 36966                  4.90                    4.80
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.58                   4.73
# 1                           4.00                   4.67
# 2                           4.79                   4.82
# 3                           5.00                   5.00
# 4                           4.76                   4.80
# ...                          ...                    ...
# 36962                       4.80                   4.90
# 36963                       4.80                   4.90
# 36964                       4.80                   4.90
# 36965                       4.80                   4.90
# 36966                       4.80                   4.90
#
#        review_scores_communication  review_scores_location  \
# 0                             4.85                    4.64
# 1                             5.00                    4.67
# 2                             4.88                    4.41
# 3                             5.00                    4.83
# 4                             4.83                    4.77
# ...                            ...                     ...
# 36962                         4.90                    4.90
# 36963                         4.90                    4.90
# 36964                         4.90                    4.90
# 36965                         4.90                    4.90
# 36966                         4.90                    4.90
#
#        review_scores_value  calculated_host_listings_count  reviews_per_month
# 0                     4.64                            11.0               0.22
# 1                     4.67                             3.0               0.02
# 2                     4.65                             6.0               0.22
# 3                     4.92                             1.0               0.51
# 4                     4.60                             1.0               0.24
# ...                    ...                             ...                ...
# 36962                 4.80                            26.0               0.70
# 36963                 4.80                             1.0               0.70
# 36964                 4.80                             4.0               0.70
# 36965                 4.80                             2.0               0.70
# 36966                 4.80                             6.0               0.70
#
# [36967 rows x 26 columns]

# %%
#corroboramos valores atipicos de dataframe
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# host_listings_count               205
# host_total_listings_count         368
# accommodates                      730
# bathrooms                         746
# bedrooms                          505
# beds                              441
# price                              91
# minimum_nights                    174
# maximum_nights                      0
# minimum_nights_avg_ntm            185
# maximum_nights_avg_ntm              0
# availability_30                     0
# availability_60                     0
# availability_90                     0
# availability_365                    0
# number_of_reviews_ltm             844
# number_of_reviews_l30d            967
# review_scores_rating              538
# review_scores_accuracy            511
# review_scores_cleanliness         621
# review_scores_checkin             665
# review_scores_communication       721
# review_scores_location            794
# review_scores_value               669
# calculated_host_listings_count    832
# reviews_per_month                 726
# dtype: int64

# %%
#remplazamos valores atipicos (nulos) del dataframe con mean 
#realizamos una copia del datframe
data_clean=data3.copy()
data_clean=data_clean.fillna(round(data3.mean(),1))
data_clean
# Out:
#        host_listings_count  host_total_listings_count  accommodates  \
# 0                     12.0                       14.0           2.0
# 1                      3.0                        5.0           2.0
# 2                     11.0                       12.0           4.0
# 3                      1.0                        2.0           4.0
# 4                      1.0                        2.0           2.0
# ...                    ...                        ...           ...
# 36962                 26.0                       26.0           3.0
# 36963                  1.0                        1.0           6.0
# 36964                  4.0                        7.0           4.0
# 36965                  2.0                        2.0           2.0
# 36966                  6.0                        7.0           4.0
#
#        bathrooms  bedrooms  beds  price  minimum_nights  maximum_nights  \
# 0            2.0       1.0   1.0  270.0             5.0             358
# 1            1.0       0.0   4.0  300.0             7.0             365
# 2            1.0       1.0   1.0  279.0             6.0              90
# 3            2.0       2.0   2.0  447.0             3.0              30
# 4            1.0       1.0   1.0  354.0             2.0              15
# ...          ...       ...   ...    ...             ...             ...
# 36962        1.0       1.0   3.0  125.0             1.0             365
# 36963        1.0       1.0   2.0  232.0             1.0             365
# 36964        1.0       1.0   2.0  200.0             1.0             365
# 36965        1.0       1.0   1.0  171.0             1.0             365
# 36966        1.0       1.0   2.0  300.0             1.0             365
#
#        minimum_nights_avg_ntm  ...  number_of_reviews_l30d  \
# 0                         5.0  ...                     1.0
# 1                         7.0  ...                     0.0
# 2                         5.7  ...                     0.0
# 3                         3.2  ...                     2.0
# 4                         2.0  ...                     0.0
# ...                       ...  ...                     ...
# 36962                     1.0  ...                     0.0
# 36963                     1.4  ...                     0.0
# 36964                     1.0  ...                     0.0
# 36965                     1.0  ...                     0.0
# 36966                     1.0  ...                     0.0
#
#        review_scores_rating  review_scores_accuracy  \
# 0                      4.69                    4.82
# 1                      4.67                    5.00
# 2                      4.71                    4.82
# 3                      5.00                    4.94
# 4                      4.68                    4.80
# ...                     ...                     ...
# 36962                  4.90                    4.80
# 36963                  4.90                    4.80
# 36964                  4.90                    4.80
# 36965                  4.90                    4.80
# 36966                  4.90                    4.80
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.58                   4.73
# 1                           4.00                   4.67
# 2                           4.79                   4.82
# 3                           5.00                   5.00
# 4                           4.76                   4.80
# ...                          ...                    ...
# 36962                       4.80                   4.90
# 36963                       4.80                   4.90
# 36964                       4.80                   4.90
# 36965                       4.80                   4.90
# 36966                       4.80                   4.90
#
#        review_scores_communication  review_scores_location  \
# 0                             4.85                    4.64
# 1                             5.00                    4.67
# 2                             4.88                    4.41
# 3                             5.00                    4.83
# 4                             4.83                    4.77
# ...                            ...                     ...
# 36962                         4.90                    4.90
# 36963                         4.90                    4.90
# 36964                         4.90                    4.90
# 36965                         4.90                    4.90
# 36966                         4.90                    4.90
#
#        review_scores_value  calculated_host_listings_count  reviews_per_month
# 0                     4.64                            11.0               0.22
# 1                     4.67                             3.0               0.02
# 2                     4.65                             6.0               0.22
# 3                     4.92                             1.0               0.51
# 4                     4.60                             1.0               0.24
# ...                    ...                             ...                ...
# 36962                 4.80                            26.0               0.70
# 36963                 4.80                             1.0               0.70
# 36964                 4.80                             4.0               0.70
# 36965                 4.80                             2.0               0.70
# 36966                 4.80                             6.0               0.70
#
# [36967 rows x 26 columns]

# %%
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# host_listings_count               0
# host_total_listings_count         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# beds                              0
# price                             0
# minimum_nights                    0
# maximum_nights                    0
# minimum_nights_avg_ntm            0
# maximum_nights_avg_ntm            0
# availability_30                   0
# availability_60                   0
# availability_90                   0
# availability_365                  0
# number_of_reviews_ltm             0
# number_of_reviews_l30d            0
# review_scores_rating              0
# review_scores_accuracy            0
# review_scores_cleanliness         0
# review_scores_checkin             0
# review_scores_communication       0
# review_scores_location            0
# review_scores_value               0
# calculated_host_listings_count    0
# reviews_per_month                 0
# dtype: int64

# %%
fig=plt.figure(figsize=(15,8))
data_clean.plot(kind='box',vert=False)
plt.title("valores atipicos del dataframe")
plt.show()

# %%
data_clean.to_csv('Datos_limpios_Brasil_estandar.csv')
